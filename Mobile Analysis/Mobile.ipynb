# %%
import pandas as pd

# %%
m =pd.read_csv('Mobile Analysis.csv',encoding='windows-1252')
m
# Out:
#                                             Phone_name   Brands   Price  \
# 0    Realme 9 Pro 5G 128 GB, 8 GB RAM, Sunrise Blue...   realme   20999
# 1    Realme 9 Pro 5G 128 GB, 6 GB RAM, Sunrise Blue...   realme   18999
# 2    Realme 9 Pro 5G 128 GB, 8 GB RAM, Aurora Green...   realme   20999
# 3    Redmi 10A 64 GB, 4 GB RAM, Sea Blue, Mobile Phone    Redmi    8299
# 4    Samsung Galaxy A33 5G 128 GB, 8 GB RAM, Awesom...  Samsung   27499
# ..                                                 ...      ...     ...
# 595  Redmi 9 Prime 64 GB, 4 GB RAM, Matte Black, Sm...    Redmi   10399
# 596  Redmi 9 Prime 64 GB, 4 GB RAM, Sunrise Flare, ...    Redmi   10399
# 597  Redmi 9 Prime 128 GB, 4 GB RAM, Space Blue, Sm...    Redmi   12499
# 598  Samsung Galaxy Z Fold4 5G 512 GB, 12 GB RAM, P...  Samsung  164999
# 599  OnePlus 10T 5G 256 GB, 16 GB RAM, Moonstone Bl...  OnePlus   55999
#
#     Internal_Storage Operating_System_Type       USB_Type 5G_Availability  \
# ...

# %%
#Check Mobile features and price list --
m[['Phone_name','Price']]
# Out:
#                                             Phone_name   Price
# 0    Realme 9 Pro 5G 128 GB, 8 GB RAM, Sunrise Blue...   20999
# 1    Realme 9 Pro 5G 128 GB, 6 GB RAM, Sunrise Blue...   18999
# 2    Realme 9 Pro 5G 128 GB, 8 GB RAM, Aurora Green...   20999
# 3    Redmi 10A 64 GB, 4 GB RAM, Sea Blue, Mobile Phone    8299
# 4    Samsung Galaxy A33 5G 128 GB, 8 GB RAM, Awesom...   27499
# ..                                                 ...     ...
# 595  Redmi 9 Prime 64 GB, 4 GB RAM, Matte Black, Sm...   10399
# 596  Redmi 9 Prime 64 GB, 4 GB RAM, Sunrise Flare, ...   10399
# 597  Redmi 9 Prime 128 GB, 4 GB RAM, Space Blue, Sm...   12499
# 598  Samsung Galaxy Z Fold4 5G 512 GB, 12 GB RAM, P...  164999
# 599  OnePlus 10T 5G 256 GB, 16 GB RAM, Moonstone Bl...   55999
#
# [600 rows x 2 columns]

# %%
#-- Find out the price of 5 most expensive phones --
(m.sort_values(by='Price',ascending=False).head())
# Out:
#                                     Phone_name Brands   Price  \
# 349  Apple iPhone 14 Pro Max 1 TB, Deep Purple  Apple  189900
# 365       Apple iPhone 14 Pro Max 1 TB, Silver  Apple  189900
# 366         Apple iPhone 14 Pro Max 1 TB, Gold  Apple  189900
# 374  Apple iPhone 14 Pro Max 1 TB, Space Black  Apple  189900
# 399           Apple iPhone 14 Pro 1 TB, Silver  Apple  179900
#
#     Internal_Storage Operating_System_Type       USB_Type 5G_Availability  \
# 349    Not Specified                   iOS  Not Specified              No
# 365    Not Specified                   iOS            Yes              No
# 366    Not Specified                   iOS            Yes              No
# 374    Not Specified                   iOS            Yes              No
# 399    Not Specified                   iOS            Yes              No
#
#     Selfie_Camera    RAM_Storage Country_of_Origin Battery_Capacity  \
# 349         12 MP  Not Specified             China    Not Specified
# ...

# %%
#Find out the price of 5 most cheapest phones
(m.sort_values(by='Price',ascending=True).head())
# Out:
#                                             Phone_name    Brands  Price  \
# 504  itel A23 Pro 8 GB, 1 GB RAM, Lake Blue, Mobile...      Itel   4040
# 503  itel A23 Pro 8 GB, 1 GB RAM, Sapphire Blue, Mo...      Itel   4040
# 535  JioPhone Next 32 GB, 2 GB RAM, Black Smartphon...  JioPhone   4499
# 534  JioPhone Next 32 GB, 2 GB RAM, Blue Smartphone...  JioPhone   4499
# 573  Samsung Galaxy M01 Core 16 GB, 1 GB, Red, Mobi...   Samsung   5199
#
#     Internal_Storage Operating_System_Type       USB_Type 5G_Availability  \
# 504             8 GB               Android  Not Specified              No
# 503             8 GB               Android  Not Specified              No
# 535    Not Specified               Android  Not Specified              No
# 534    Not Specified               Android  Not Specified              No
# 573    Not Specified               Android        USB 2.0              No
#
#     Selfie_Camera RAM_Storage Country_of_Origin Battery_Capacity  \
# ...

# %%
#List of top 5 Samsung phones with price and all features
s=m[m['Brands']=='Samsung']
(s.sort_values(by='Price',ascending=False).head())
# Out:
#                                             Phone_name   Brands   Price  \
# 598  Samsung Galaxy Z Fold4 5G 512 GB, 12 GB RAM, P...  Samsung  164999
# 551  Samsung Galaxy Z Fold4 5G 512 GB, 12 GB RAM, B...  Samsung  164999
# 542  Samsung Galaxy Z Fold2 256 GB, 12 GB RAM, Myst...  Samsung  119999
# 22   Samsung S22 Ultra 5G 512 GB, 12 GB RAM, Phanto...  Samsung  118999
# 7    Samsung S22 Ultra 5G 512 GB, 12 GB RAM, Green,...  Samsung  118999
#
#     Internal_Storage Operating_System_Type       USB_Type 5G_Availability  \
# 598           512 GB               Android            Yes              No
# 551           512 GB               Android            Yes              No
# 542    Not Specified               Android            Yes              No
# 22     Not Specified               Android  Not Specified              No
# 7      Not Specified               Android  Not Specified              No
#
#     Selfie_Camera RAM_Storage Country_of_Origin Battery_Capacity  \
# ...

# %%
#Must have android phone list then top 5 High price android phones
s=m[m['Operating_System_Type']=='Android']
(s.sort_values(by='Price',ascending=False).head())
# Out:
#                                             Phone_name   Brands   Price  \
# 551  Samsung Galaxy Z Fold4 5G 512 GB, 12 GB RAM, B...  Samsung  164999
# 598  Samsung Galaxy Z Fold4 5G 512 GB, 12 GB RAM, P...  Samsung  164999
# 542  Samsung Galaxy Z Fold2 256 GB, 12 GB RAM, Myst...  Samsung  119999
# 70   Samsung S22 Ultra 5G 512 GB, 12 GB RAM, Phanto...  Samsung  118999
# 7    Samsung S22 Ultra 5G 512 GB, 12 GB RAM, Green,...  Samsung  118999
#
#     Internal_Storage Operating_System_Type       USB_Type 5G_Availability  \
# 551           512 GB               Android            Yes              No
# 598           512 GB               Android            Yes              No
# 542    Not Specified               Android            Yes              No
# 70     Not Specified               Android  Not Specified              No
# 7      Not Specified               Android  Not Specified              No
#
#     Selfie_Camera RAM_Storage Country_of_Origin Battery_Capacity  \
# ...

# %%
#Must have android phone list then top 5 lowest price android phones
s=m[m['Operating_System_Type']=='Android']
(s.sort_values(by='Price',ascending=True).head())
# Out:
#                                             Phone_name    Brands  Price  \
# 504  itel A23 Pro 8 GB, 1 GB RAM, Lake Blue, Mobile...      Itel   4040
# 503  itel A23 Pro 8 GB, 1 GB RAM, Sapphire Blue, Mo...      Itel   4040
# 534  JioPhone Next 32 GB, 2 GB RAM, Blue Smartphone...  JioPhone   4499
# 535  JioPhone Next 32 GB, 2 GB RAM, Black Smartphon...  JioPhone   4499
# 573  Samsung Galaxy M01 Core 16 GB, 1 GB, Red, Mobi...   Samsung   5199
#
#     Internal_Storage Operating_System_Type       USB_Type 5G_Availability  \
# 504             8 GB               Android  Not Specified              No
# 503             8 GB               Android  Not Specified              No
# 534    Not Specified               Android  Not Specified              No
# 535    Not Specified               Android  Not Specified              No
# 573    Not Specified               Android        USB 2.0              No
#
#     Selfie_Camera RAM_Storage Country_of_Origin Battery_Capacity  \
# ...

# %%
# Must have IOS phone list then top 5 High price android phones
s=m[m['Operating_System_Type']=='iOS']
(s.sort_values(by='Price',ascending=False).head())
# Out:
#                                     Phone_name Brands   Price  \
# 349  Apple iPhone 14 Pro Max 1 TB, Deep Purple  Apple  189900
# 366         Apple iPhone 14 Pro Max 1 TB, Gold  Apple  189900
# 365       Apple iPhone 14 Pro Max 1 TB, Silver  Apple  189900
# 374  Apple iPhone 14 Pro Max 1 TB, Space Black  Apple  189900
# 399           Apple iPhone 14 Pro 1 TB, Silver  Apple  179900
#
#     Internal_Storage Operating_System_Type       USB_Type 5G_Availability  \
# 349    Not Specified                   iOS  Not Specified              No
# 366    Not Specified                   iOS            Yes              No
# 365    Not Specified                   iOS            Yes              No
# 374    Not Specified                   iOS            Yes              No
# 399    Not Specified                   iOS            Yes              No
#
#     Selfie_Camera    RAM_Storage Country_of_Origin Battery_Capacity  \
# 349         12 MP  Not Specified             China    Not Specified
# ...

# %%
#Write a query which phone support 5G and also top 5 phone with 5G support
s=m[m['Operating_System_Type']=='iOS']
(s.sort_values(by='Price',ascending=True).head())
# Out:
#                                             Phone_name Brands  Price  \
# 296  Apple iPhone SE 128 GB, Black (Includes Earpod...  Apple  43900
# 340  Apple iPhone 11 64 GB, Purple (without Earpods...  Apple  43900
# 351  Apple iPhone 11 64 GB, Green (without Earpods ...  Apple  43900
# 413  Apple iPhone 11 64 GB, Black (without Earpods ...  Apple  43900
# 352  Apple iPhone 11 64 GB, Yellow (without Earpods...  Apple  43900
#
#     Internal_Storage Operating_System_Type       USB_Type 5G_Availability  \
# 296           128 GB                   iOS            Yes             Yes
# 340            64 GB                   iOS  Not Specified              No
# 351            64 GB                   iOS  Not Specified              No
# 413            64 GB                   iOS  Not Specified              No
# 352            64 GB                   iOS  Not Specified              No
#
#     Selfie_Camera    RAM_Storage Country_of_Origin Battery_Capacity  \
# ...

# %%
# Total price of all mobile is to be found with brand name
m.groupby('Brands')['Price'].sum()
# Out:
# Brands
# Apple       10572900
# Infinix       200984
# Itel           42575
# JioPhone        8998
# Mi            440488
# Moto           19998
# Motorola      520979
# Nokia         269778
# OnePlus       801977
# Oppo          629336
# Redmi        1086928
# Samsung      4148103
# Tecno          41196
# Vivo         1122844
# Xiaomi       1282956
# realme       1461118
# Name: Price, dtype: int64
